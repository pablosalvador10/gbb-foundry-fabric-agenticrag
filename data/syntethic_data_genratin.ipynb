# %%
import os

# Define the target directory
target_directory = os.getcwd()  # change your directory here

# Check if the directory exists
if os.path.exists(target_directory):
    # Change the current working directory
    os.chdir(target_directory)
    print(f"Directory changed to {os.getcwd()}")
else:
    print(f"Directory {target_directory} does not exist.")
# Out:
# Directory changed to c:\Users\pablosal\Desktop\azure-ai-agent-services-demo\data

# %%
from docx import Document
from docx.shared import Pt
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT

# Create a new Document
doc = Document()

# Title
title = doc.add_heading(level=1)
run = title.add_run(
    "Ambulatory Cardiac Monitoring Devices Market Research Report 2024-2028"
)
run.bold = True
title.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER

# Subtitle
subtitle = doc.add_paragraph()
run = subtitle.add_run("Prepared by Contoso Enterprises Market Research Team")
run.italic = True
subtitle.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER

# Introduction
doc.add_heading("Introduction", level=2)
doc.add_paragraph(
    "This report provides a comprehensive analysis of the Ambulatory Cardiac Monitoring Devices market from 2024 to 2028. "
    "It aims to offer Product Managers and R&D teams valuable insights into market trends, growth drivers, challenges, and opportunities."
)

# Market Overview
doc.add_heading("Market Overview", level=2)
doc.add_paragraph(
    "The global ambulatory cardiac monitoring devices market is experiencing significant growth, driven by the increasing prevalence of cardiovascular diseases, technological advancements, and a growing emphasis on preventive healthcare. "
    "According to Grand View Research, the market was valued at USD 5.77 billion in 2022 and is expected to expand at a CAGR of 10.4% from 2023 to 2030, reaching approximately USD 12.72 billion by 2030."
)

# Market Segmentation
doc.add_heading("Market Segmentation", level=2)

# By Device Type
doc.add_heading("By Device Type", level=3)
doc.add_paragraph(
    "1. **ECG Devices**: Accounted for the largest market share of 38.9% in 2022. The demand is expected to grow due to the increasing incidences of cardiovascular diseases and the devices' high accuracy and continuous monitoring capabilities."
)
doc.add_paragraph(
    "2. **Mobile Cardiac Telemetry (MCT)**: Expected to show the fastest CAGR of 13.2% over the forecast period, driven by a rising preference for on-the-go monitoring devices."
)

# By End-User
doc.add_heading("By End-User", level=3)
doc.add_paragraph(
    "1. **Hospitals & Clinics**: Dominated the market with a share of 50.5% in 2022, attributed to the rising incidence of cardiovascular disorders and the need for continuous supervision in critical cardiac situations."
)
doc.add_paragraph(
    "2. **Ambulatory Care Centers**: Expected to expand at a CAGR of 10.3% during the forecast period, catering to the interests of the growing geriatric population by providing efficient, convenient, and cost-effective alternatives to hospital-based outpatient procedures."
)

# Market Drivers
doc.add_heading("Market Drivers", level=2)
doc.add_paragraph(
    "1. **Increasing Prevalence of Cardiovascular Diseases**: The rising number of cardiac disorders necessitates continuous monitoring, boosting the demand for ambulatory cardiac monitoring devices."
)
doc.add_paragraph(
    "2. **Technological Advancements**: Innovations such as mobile cardiac telemetry and implantable loop recorders enhance patient monitoring and contribute to market growth."
)
doc.add_paragraph(
    "3. **Growing Geriatric Population**: An aging population is more susceptible to heart-related conditions, increasing the need for monitoring devices."
)

# Market Challenges
doc.add_heading("Market Challenges", level=2)
doc.add_paragraph(
    "1. **High Costs**: The expenses associated with advanced monitoring devices can be a barrier to widespread adoption."
)
doc.add_paragraph(
    "2. **Regulatory Hurdles**: Stringent regulatory procedures may delay product approvals and market entry."
)

# Opportunities for Product Managers and R&D Teams
doc.add_heading("Opportunities for Product Managers and R&D Teams", level=2)
doc.add_paragraph(
    "1. **Development of Cost-Effective Solutions**: Innovating affordable monitoring devices can capture a broader market segment."
)
doc.add_paragraph(
    "2. **Integration with Telemedicine**: Aligning devices with telehealth platforms can enhance remote patient monitoring and appeal to healthcare providers."
)
doc.add_paragraph(
    "3. **Focus on Emerging Markets**: Targeting regions with rising healthcare infrastructure offers potential growth opportunities."
)

# Regional Insights
doc.add_heading("Regional Insights", level=2)
doc.add_paragraph(
    "1. **North America**: Dominated the market with a share of 42.8% in 2022, attributed to key market players engaging in collaborations and partnerships, coupled with a well-structured regulatory framework and reimbursement scenario."
)
doc.add_paragraph(
    "2. **Asia Pacific**: Expected to witness the fastest CAGR of 11.3% over the forecast period, driven by partnerships, collaborations, product launches, and acquisitions by key players to strengthen their market position."
)

# Competitive Landscape
doc.add_heading("Competitive Landscape", level=2)
doc.add_paragraph(
    "The market is characterized by the presence of several key players engaging in partnerships, acquisitions, and collaborations to increase their market share. Notable companies include:"
)
doc.add_paragraph(
    "1. **Koninklijke Philips N.V.**: Acquired BioTelemetry, Inc. to strengthen its cardiac care product portfolio."
)
doc.add_paragraph(
    "2. **GE Healthcare**: Collaborated with AMC Health to integrate remote patient monitoring platforms."
)
doc.add_paragraph(
    "3. **Medtronic Plc**: Offers a range of cardiac monitoring solutions and continues to invest in R&D."
)

# Conclusion
doc.add_heading("Conclusion", level=2)
doc.add_paragraph(
    "The ambulatory cardiac monitoring devices market is poised for substantial growth from 2024 to 2028. Product Managers and R&D teams should focus on technological innovations, cost reduction, and strategic collaborations to capitalize on emerging opportunities."
)

# Disclaimer
doc.add_paragraph(
    "©2025 Contoso Enterprises. All data presented is based on synthetic market insights and is intended solely for strategic analysis."
)

# Save the document
doc.save("Ambulatory_Cardiac_Monitoring_Devices_Market_Report_2024-2028.docx")
